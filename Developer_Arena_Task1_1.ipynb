# %% [markdown]
# <a href="https://colab.research.google.com/github/Wazir123456/The-Developer-Arena-Internship-Tasks/blob/main/Developer_Arena_Task1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Hello world Program

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# Variables for Personal Information

# %%
name = "Vipul Jadhav"
age = 21
city = "Navi-Mumbai"

print("Name:", name)
print("Age:", age)
print("City:", city)
# Out:
# Name: Vipul Jadhav
# Age: 21
# City: Navi-Mumbai

# %% [markdown]
# Basic Math Calculations

# %%
a = int(input("Enter the first number"))
b = int(input("Enter a  second number"))

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Power:", a ** b)
# Out:
# Enter the first number10
# Enter a  second number5
# Addition: 15
# Subtraction: 5
# Multiplication: 50
# Division: 2.0
# Power: 100000

# %% [markdown]
# List of Favorite Foods

# %%
foods = ["Vadapav", "Samosa Pav", "SevPuri", "Chinese Bhel"]

print("My favourite foods:")
print(foods)

print("First food:", foods[0])
print("Last food:", foods[-1])
# Out:
# My favourite foods:
# ['Vadapav', 'Samosa Pav', 'SevPuri', 'Chinese Bhel']
# First food: Vadapav
# Last food: Chinese Bhel

# %% [markdown]
# Building Bio-Data Program

# %%
name = "Vipul Jadhav"
age = 21
city = "Navi-Mumbai"
hobby = "Cricket"

print(" BIO DATA ")
print("Name:", name)
print("Age:", age)
print("City:", city)
print("Hobby:", hobby)
# Out:
#  BIO DATA
# Name: Vipul Jadhav
# Age: 21
# City: Navi-Mumbai
# Hobby: Cricket

# %% [markdown]
# Personal Introduction Program

# %%
name = input("Enter your name: ")
age = input("Enter your age: ")
hobby = input("Enter your hobby: ")

print("\n Welcome Message ")
print(f"Hello everyone . My name is {name}.I am {age} years old and I love {hobby}.")
print("Nice to meet you all! 😊")
# Out:
# Enter your name: Vipul Jadhav
# Enter your age: 21
# Enter your hobby: Cricket
#
#  Welcome Message
# Hello everyone . My name is Vipul Jadhav.I am 21 years old and I love Cricket.
# Nice to meet you all! 😊
